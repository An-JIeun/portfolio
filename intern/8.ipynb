# %% [markdown]
# # 식품의약품안전처_의료기기 GMP 신청품목 현황 (식의약헬스종합정보)
# ---
# - 작성자 : 안지은
# - 실행일 : 2023-01-10

# %%
import requests
import pprint
import json
import pandas as pd
from datetime import datetime,  timedelta
import tqdm 
from tqdm import tqdm

import warnings
warnings.filterwarnings('ignore')

key = '7bBeVcu1HiKEYVutnwGstfISHvCJKzXcizQ2iFZlhBCaQobHPqOod8G%2BcwO05R81TptPWRtVcKUSqmhqOqCGXQ%3D%3D'

# %%
# 총 데이터 수 구하는 함수
def get_total_cnt(key):
    url = 'https://apis.data.go.kr/1471000/MdeqGMPAplyPrdlstStusService02/getMdeqGMPAplyPrdlstStusInq02?serviceKey=%s&pageNo=1&type=json'%(key)
    response = requests.get(url, verify=False)
    contents = response.text
    json_ob = json.loads(contents)
    cnt = int(json_ob['body']['totalCount'])
    return cnt

# %%
# api 컨텐츠(json - data) 받아오는 함수
def get_api_conts(key,page):
    
    url = 'https://apis.data.go.kr/1471000/MdeqGMPAplyPrdlstStusService02/getMdeqGMPAplyPrdlstStusInq02?serviceKey=%s&pageNo=%s&numOfRows=100&type=json'%(key,str(page))
    
    response = requests.get(url, verify=False)
    contents = response.text
    json_ob = json.loads(contents)
    data = json_ob['body']['items']
    
    return data

# %% [markdown]
# ### API 가져오기
# ---
# - 한 페이지 당  100개 씩 제한
# - 총 39746개 행
# - body - item 리스트 안에 다시 딕셔너리로 item이 있음

# %%
gmp = []
cnt = get_total_cnt(key)
page = int(cnt/100) + 1
for i in tqdm(range(1,page+1)):
    js = get_api_conts(key,i)
    for item in js:
        gmp.append(item['item'])
# Out:
# 100%|██████████| 134/134 [01:23<00:00,  1.60it/s]

# %% [markdown]
# ### 데이터 프레임 변환
# ---
# - 컬럼명 : API 목록

# %%
gmp_df = pd.json_normalize(gmp)
gmp_df.columns = ['최초심사여부','진행상태코드','진행상태','담당자승인여부','심사청 코드','심사청',
                    '심사방식코드','심사방식','적용기준구분코드','적용기준구분','품모경','대표품목유무',
                    '품목군제외여부','심사신청일련번호','심사신청품목일련번호','분류번호','등급','형명',
                    '접수번호','제조자국가코드','제조자국가','제조자 명','제조자 주소','상태','수출용 여부']
gmp_df
# Out:
#                        품명        수량      사용량      재고량  \
# 0           브롬화수소산덱스트로메토판       500        0        0
# 1           브롬화수소산덱스트로메토판       500        0        0
# 2           브롬화수소산덱스트로메토판       500      100      400
# 3           브롬화수소산덱스트로메토판       500      100      400
# 4           브롬화수소산덱스트로메토판       400      100      300
# ...                   ...       ...      ...      ...
# 13386  덱스트로메토르판브롬화수소산염수화물  10519.29  2272.82  8246.47
# 13387              부프레노르핀       200        0        0
# 13388              부프레노르핀     15000        0        0
# 13389  부프레노르핀 포 시스템 슈터빌리티        80        0       70
# 13390       부프레노르핀 엔 옥사이드       210        0        8
#
#                                                     사용내역  \
# 0                   자사에서는 2006.1.8. 현재 표준품 분양을 받지 않았습니다.
# 1                                                      1
# 2           2007-03-08 Lot S-0450207(200kg) 자가품질관리용으로 사용
# 3           2007-03-08 LOT S-0450207(200kg) 자가품질관리용으로 사용
# 4           2007-07-27 LOT S-1060407(100kg) 자가품질관리용으로 사용
# ...                                                  ...
# 13386                     상용표준품(S-0220222) : 2,272.82 mg
# 13387  Buprenorphine impurity A \n취급승인양 : 200 mg\n수불한...
# 13388    취급승인양 : 15,000 mg\n수불한양 : -\n실제사용량 : -\n재고량 : -
# 13389  취급승인양 : 80mg\n수불한양 : 70mg\n실제사용량 : 0 mg\n재고량 :...
# 13390  취급승인양 : 208 mg\n수불한양 : 8 mg\n실제사용량 : 0 mg\n재고량...
#
#                                   구입처
# 0      예정 구입처 : 식품의약품의약품평가부 마약신경계의약품팀
# 1                                   1
# 2                식품의약품의약품평가부마약신경계의약품팀
# 3                식품의약품안전청평가부마약신경계의약품팀
# 4                식품의약품의약품평가부마약신경계의약품팀
# ...                               ...
# 13386                      국전약품 상용표준품
# 13387                         구입내역 없음
# 13388                         구입내역 없음
# 13389                              EP
# 13390                             TRC
#
# [13391 rows x 6 columns]

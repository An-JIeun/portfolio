# %% [markdown]
# # 식품의약품안전처_연도별 마약류취급자 정보(식의약헬스종합정보)
# ---
# - 작성자 : 안지은
# - 실행일 : 2023-01-10

# %%
import requests
import pprint
import json
import pandas as pd
from datetime import datetime,  timedelta
import tqdm 
from tqdm import tqdm

import warnings
warnings.filterwarnings('ignore')

key = '7bBeVcu1HiKEYVutnwGstfISHvCJKzXcizQ2iFZlhBCaQobHPqOod8G%2BcwO05R81TptPWRtVcKUSqmhqOqCGXQ%3D%3D'

# %%
# 총 데이터 수 구하는 함수
def get_total_cnt(key):
    url = 'https://apis.data.go.kr/1471000/YrNarkAgntStusService01/getYrNarkAgntStusInq02?serviceKey=%s&type=json'%(key)
    response = requests.get(url, verify=False)
    contents = response.text
    json_ob = json.loads(contents)
    cnt = int(json_ob['body']['totalCount'])
    return cnt

# %%
# api 컨텐츠(json - data) 받아오는 함수
def get_api_conts(key,page):
    
    url = 'https://apis.data.go.kr/1471000/YrNarkAgntStusService01/getYrNarkAgntStusInq02?serviceKey=%s&pageNo=%s&numOfRows=100&type=json'%(key,str(page))
    
    response = requests.get(url, verify=False)
    contents = response.text
    json_ob = json.loads(contents)
    data = json_ob['body']['items']
    
    return data

# %% [markdown]
# ### API 가져오기
# ---
# - 한 페이지 당  100개 씩 제한
# - 총 13391개 행
# - body - item 리스트 안에 다시 딕셔너리로 item이 있음

# %%
taker = []
cnt = get_total_cnt(key)
page = int(cnt/100) + 1
for i in tqdm(range(1,page+1)):
    js = get_api_conts(key,i)
    for item in js:
        taker.append(item['item'])
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]

# %% [markdown]
# ### 데이터 프레임 변환
# ---
# - 컬럼명 : API 목록

# %%
taker_df = pd.json_normalize(taker)
taker_df.columns = ['연도','건수']
taker_df
# Out:
#       연도   건수
# 0   1977    3
# 1   1989    2
# 2   1997    2
# 3   2005   11
# 4   2013   62
# 5   2021  264
# 6   1980    1
# 7   1990    1
# 8   1998    4
# 9   2006   28
# 10  2014   48
# 11  2022  253
# 12  1955    2
# 13  1981    1
# 14  1991    1
# 15  1999    4
# 16  2007   38
# 17  2015  152
# 18  2023    1
# 19  1960    1
# 20  1982    2
# 21  1992    2
# 22  2000    4
# 23  2008   27
# 24  2016  164
# 25  1961    1
# 26  1984    3
# 27  1993    4
# 28  2001    5
# 29  2009   22
# 30  2017  121
# 31  1967    1
# 32  1985    5
# 33  1994    6
# 34  2002    9
# 35  2010   22
# 36  2018  127
# 37  1970   11
# 38  1986    5
# 39  1995    5
# 40  2003   41
# 41  2011   23
# 42  2019  117
# 43  1971    5
# 44  1987    1
# 45  1996    3
# 46  2004   13
# 47  2012  146
# 48  2020  197
